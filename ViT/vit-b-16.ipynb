# %% [markdown]
# # Import

# %%
try:
    from torchinfo import summary
except:
    print("[INFO] Couldn't find torchinfo... installing it.")
    # !pip install -q torchinfo
    from torchinfo import summary

# %%
try:
    import wandb
except:
    # !pip install wandb
    import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import pandas as pd
import seaborn as sns
import os
from pathlib import Path
import re
import random
import matplotlib.pyplot as plt
import math
import torch

from PIL import Image
from pandas import DataFrame
from typing import Tuple, Dict, List
from torch.utils.data import Dataset, DataLoader

"""
Contains functions for training and testing a PyTorch model.
"""
from torchinfo import summary
from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim

# %%
import pandas as pd
import seaborn as sns
import os

import requests
import zipfile
from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# # Directory

# %%
# Setup path to data folder
data_path = Path.cwd()
image_path = data_path / 'NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data'

# If the image folder doesn't exist, download it and prepare it...
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)

    # Download pizza, steak, sushi data
    url = "https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/bbmmm4wgr8-4.zip"
    response = requests.get(url, stream=True)
    total_size = int(response.headers.get('content-length', 0))

    print(f"Downloading data ({total_size / 1024 / 1024:.2f} MBs)...")

    with open(data_path / "NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data.zip", "wb") as f, tqdm(unit="B", unit_scale=True, unit_divisor=1024, total=total_size, desc="Downloading", bar_format="{percentage:.2f}%|{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}, {rate_fmt}]") as progress:
        for chunk in response.iter_content(chunk_size=1024):
            if chunk:
                f.write(chunk)
                progress.update(len(chunk))

    print("\nData successfully downloaded.")

    print("Extracting data...")
    with zipfile.ZipFile(data_path / "NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data.zip", "r") as zip_ref:
        zip_ref.extractall(data_path)

    print("Data successfully extracted.")
# Out:
# Did not find /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data directory, creating one...
# Downloading data (3048.40 MBs)...
# 100.00%|██████████| 2.98G/2.98G [1:12:40<00:00, 733kB/s]
# Data successfully downloaded.
# Extracting data...
# Data successfully extracted.

# %%
# Setup path for target directory
target_directory = image_path / 'patch'
print(f"Target directory: {target_directory}")
# Out:
# Target directory: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch

# %%
with zipfile.ZipFile(target_directory/'images-patches.zip', "r") as zip_ref:
        print("Unzipping data...")
        zip_ref.extractall(data_path)
# Out:
# Unzipping data...

# %%
zip_path = target_directory/'images-patches.zip'

# %%
#!unzip "/content/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images-patches.zip" -d "/content/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch"

# %%
# !unzip "/kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images-patches.zip" -d "/kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch"
# Out:
# Archive:  /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images-patches.zip
#    creating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/patch/
#    creating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/patch/patch/
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/patch/patch/images-patches.zip
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/patch/patch/sabpatch_parsed_folders.csv
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/patch/patch/sabpatch_parsed_test.csv

# %%
#!unzip "/content/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/patch/patch/images-patches.zip" -d "/content/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch"

# %%
# !unzip "/kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/patch/patch/images-patches.zip" -d "/kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch"
# Out:
# Archive:  /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/patch/patch/images-patches.zip
#    creating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0008.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0011.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0014.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0016.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0017.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0019.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0022.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0023.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0024.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0029.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0031.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0046.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0047.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0051.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0052.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0057.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0068.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0072.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0075.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0080.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0083.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0097.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0110.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0111.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0112.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0114.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0118.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0120.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0129.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0133.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0135.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0143.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0147.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0153.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0155.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0157.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0162.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0163.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0165.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0167.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0175.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0176.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0177.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0182.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0188.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0189.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0190.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0195.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0196.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0204.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0205.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0209.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0213.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0216.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0217.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0219.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0220.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0223.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0225.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0228.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0229.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0232.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0242.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0248.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0252.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0254.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0259.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0261.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0263.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0272.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0273.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0274.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0285.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0286.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0300.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0302.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0303.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0305.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0308.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0310.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0312.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0313.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0316.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0318.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0319.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0324.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0327.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0328.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0335.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0348.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0354.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0355.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0364.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0370.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0371.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0372.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0377.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0378.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0381.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0385.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0390.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0398.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0410.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0412.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0417.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0422.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0424.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0426.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0427.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0430.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0432.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0438.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0439.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0441.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0442.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0446.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0450.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0451.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0458.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0459.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0462.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0468.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0477.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0482.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0493.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0494.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0496.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0498.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0500.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0502.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0503.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0509.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0522.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0523.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0526.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0527.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0529.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0530.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0531.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0533.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0536.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0537.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0539.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0544.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0547.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0552.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0560.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0567.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0576.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0577.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0579.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0584.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0597.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0599.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0608.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0611.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0613.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0614.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0622.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0625.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0632.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0633.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0634.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0635.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0636.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0641.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0648.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0649.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0650.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0654.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0656.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0663.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0664.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0666.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0668.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0673.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0683.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0691.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0692.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0693.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0695.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0699.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0704.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0705.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0711.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0715.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0722.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0726.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0729.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0730.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0734.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0735.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0741.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0743.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0744.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0745.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0747.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0753.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0759.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0778.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0787.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0789.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0791.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0792.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0797.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0816.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0831.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0835.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0839.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0840.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0845.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0846.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0847.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0849.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0850.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0855.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0862.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0863.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0864.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0868.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0871.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0873.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0874.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0877.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0879.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0888.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0889.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0890.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0892.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0893.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0896.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0898.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0904.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0909.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0910.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0911.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0912.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0913.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0915.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0917.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0921.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0929.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0933.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0937.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0939.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0941.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0944.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0957.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0960.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0961.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0969.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0972.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0976.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0977.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0979.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0986.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0987.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0993.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0997.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0998.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p0999.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1000.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1004.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1005.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1012.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1013.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1015.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1018.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1020.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1028.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1029.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1031.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1033.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1035.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1040.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1044.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1045.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1050.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1058.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1061.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1065.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1066.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1072.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1075.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1077.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1084.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1085.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1086.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1089.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1093.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1097.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1099.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1104.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1105.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1109.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1116.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1125.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1138.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1139.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1141.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1142.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1144.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1149.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1152.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p1154.png
# ...
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3235.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3237.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3238.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3260.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3262.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3264.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3270.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3276.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3280.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3285.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3291.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3300.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3301.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3302.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3312.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3314.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3318.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3319.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3320.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3326.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3332.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3339.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3341.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3346.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3349.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3353.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3354.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3357.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3358.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3363.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3375.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3386.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3393.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3402.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3403.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3414.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3421.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3425.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3430.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3431.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3452.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3462.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3467.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3474.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3476.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3481.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3483.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3485.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3487.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3495.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3496.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3498.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3502.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3509.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3513.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3514.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3518.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3520.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3523.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3527.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3531.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3535.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3537.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3538.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3553.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3577.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3582.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3583.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3584.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3586.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3593.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3598.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3608.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3612.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3613.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3617.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3622.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3624.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3629.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3634.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3644.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3646.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3649.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3656.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3658.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3659.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3662.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3679.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3680.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3699.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3700.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3707.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3709.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3714.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3721.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3722.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3730.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3737.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3738.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3746.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3756.png
#   inflating: /kaggle/working/NDB-UFES An oral cancer and leukoplakia dataset composed of histopathological images and patient data/patch/images/p3762.png

# %%
image_dir = target_directory / 'images'
train_df = pd.read_csv(target_directory/'sabpatch_parsed_folders.csv')
train_ds = train_df[['path','lesion']]
test_df = pd.read_csv(target_directory/'sabpatch_parsed_test.csv')
test_ds = test_df[['path','lesion']]

# %% [markdown]
# # Global Parameters

# %%
ALPHA = 0.0001 ## Learning Rate
EPOCH = 50  ## Epochs
BATCH_SIZE = 32
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]

# %% [markdown]
# # Custom Image Dataset

# %%
# Write a custom dataset class (inherits from torch.utils.data.Dataset)
class ImageFolderCustom(Dataset):

    # 1. Initialize with a targ_dir and transform (optional) parameter
    def __init__(self,
                 targ_dir: str,
                 path_df: DataFrame,
                 transform=None) -> None:

        # Get all image paths, classes
        self.img_df = path_df

        # Set all images to proper path
        self.img_df['path'] = self.check_path(targ_dir)

        self.paths = list(self.img_df['path'])

        # Setup transforms
        self.transform = transform

        self.classes, self.class_to_idx = self.find_classes()

    # 2. check if its already in proper format
    def check_path(self,
                   targ_dir: str) -> DataFrame:
        if str(targ_dir) in self.img_df.iloc[0,0]:
            return self.img_df['path'].astype('string')
        else:
            return str(targ_dir)+ '/' +  self.img_df['path'].astype('string')

    # 3. Make function to load images
    def load_image(self,
                   index: int) -> Image.Image:
        "Opens an image via a path and returns it."
        image_path = self.img_df.iloc[index, 0]
        return Image.open(image_path)

    # 4. Overwrite the __len__() method (optional but recommended for subclasses of torch.utils.data.Dataset)
    def __len__(self) -> int:
        "Returns the total number of samples."
        return self.img_df.shape[0]

    # 5. Overwrite the __getitem__() method (required for subclasses of torch.utils.data.Dataset)
    def __getitem__(self,
                    index: int) -> Tuple[torch.Tensor, int]:
        "Returns one sample of data, data and label (X, y)."
        img = self.load_image(index)
        class_name  = self.img_df.iloc[index, 1] # expects path in data_folder/class_name/image.jpeg
        class_idx = self.class_to_idx[class_name]

        # Transform if necessary
        if self.transform:
            return self.transform(img), class_idx # return data, label (X, y)
        else:
            return img, class_idx # return data, label (X, y)


    def find_classes(self) -> Tuple[List[str], Dict[str, int]]:

        col = self.img_df.columns
        # 1. Get the class names by scanning the target directory
        classes = sorted(self.img_df[col[1]].unique())

        # 2. Raise an error if class names not found
        if not classes:
            raise FileNotFoundError(f"Couldn't find any classes.")

        # 3. Create a dictionary of index labels (computers prefer numerical rather than string labels)
        class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}
        return classes, class_to_idx

# %%
def create_dataloader(dir,
                      train_ds: DataFrame,
                      test_ds: DataFrame) -> Tuple[DataLoader[float], DataLoader[float], List[str]]:


    # train_transforms = transforms.Compose([
    #     #transforms.Resize((64, 64)),
    #     transforms.RandomHorizontalFlip(p=0.5),
    #     #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    #     transforms.ToTensor()
    # ])


    manual_transforms = transforms.Compose([
        transforms.Resize((224, 224)), # 1. Reshape all images to 224x224 (though some models may require different sizes)
        transforms.ToTensor(), # 2. Turn image values to between 0 & 1
        transforms.Normalize(mean = MEAN, # 3. A mean of [0.485, 0.456, 0.406] (across each colour channel)
                         std = STD)
    ])



    # test_transforms = transforms.Compose([
    #     #transforms.Resize((64, 64)),
    #     transforms.ToTensor(),
    # ])


    train_data = ImageFolderCustom(targ_dir = dir,
                                          path_df = train_ds,
                                          transform= manual_transforms)

    test_data = ImageFolderCustom(targ_dir = dir,
                                          path_df = test_ds,
                                          transform= manual_transforms)



    classes, class_to_idx = train_data.find_classes()

    # Turn train, test and eval Dataset's into DataLoader's

    train_dataloader = DataLoader(dataset=train_data, # use custom created train Dataset
                                        batch_size=BATCH_SIZE, # how many samples per batch?
                                        num_workers=0, # how many subprocesses to use for data loading? (higher = more)
                                        shuffle=True) # shuffle the data?

    test_dataloader = DataLoader(dataset=test_data, # use custom created test Dataset
                                        batch_size=BATCH_SIZE,
                                        num_workers=0,
                                        shuffle=False) # don't usually need to shuffle testing data

    return train_dataloader, test_dataloader, classes

# %%
train_dataloader, test_dataloader, classes = create_dataloader(dir=image_dir, train_ds=train_ds, test_ds=test_ds)
# Out:
# /tmp/ipykernel_34/1968766816.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.img_df['path'] = self.check_path(targ_dir)

# %%
train_dataloader, test_dataloader, classes
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7be8abf3bbe0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7be8abf38af0>,
#  ['OSCC', 'With dysplasia', 'Without dysplasia'])

# %% [markdown]
# # Model Class

# %%
class Engine():

    wandb.init(
    project="vit-b-16",
    config={
            "epochs": EPOCH,
            "batch_size": BATCH_SIZE,
            "lr": ALPHA,
            "architecture": "ViT",
            })




    def __init__(self,
                 model,
                 loss_fn,
                 optimizer,
                 device,
                 early_stopping = False):

        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.device = device

        self.early_stopping = early_stopping
        self.counter = 0
        self.early_stop = False # type: ignore
        self.best_score = None

        # Copy your config
        self.config = wandb.config

    def model_summary(self,
                      input_size,
                      col_width = 20,):

        return summary(self.model,
                input_size = input_size, # make sure this is "input_size", not "input_shape" (batch_size, color_channels, height, width)
                col_names = ["input_size", "output_size", "num_params", "trainable"],
                col_width = col_width,
                row_settings = ["var_names"])

    def check_early_stop(self,
                   val_loss,
                   delta,
                   verbose,
                   patience):

        score = -val_loss
        # print(verbose)
        if self.best_score is None:
            self.best_score = score

        elif score < self.best_score + delta:
            self.counter += 1

            if verbose:
                print(f"Early stopping counter: {self.counter} out of {patience}")

            if self.counter >= patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.early_stop = False
            self.counter = 0


    def train_step(self, epoch):

        y_tr_true, y_tr_pred= [], []
        # Put model in train mode
        self.model.train()

        # Setup train loss and train accuracy values
        train_loss, train_acc = 0, 0

        n_steps_per_epoch = math.ceil(len(self.train_dataloader) / self.config.batch_size)

        example_ct = 0
        # Loop through data loader data batches
        for i, data in enumerate(tqdm(self.train_dataloader, desc=f'Epoch {epoch + 1}/{self.epochs}', unit='batch')):
            # Send data to target device
            X_train, y_train = data

            y_tr_true.extend(y_train) # collect all training labels

            X_train = X_train.to(self.device)
            y_train = y_train.to(self.device)

            # 1. Forward pass

            outputs = self.model(X_train)
            _, y_pred = torch.max(outputs, 1) # max along an axis gives both max val as well as index
            y_tr_pred.extend(y_pred.data.cpu())

            # 2. Calculate  and accumulate loss
            loss = self.loss_fn(outputs, y_train)

            train_loss += loss.item()

            # 3. Optimizer zero grad
            self.optimizer.zero_grad()

            # 4. Loss backward
            loss.backward()

            # 5. Optimizer step
            self.optimizer.step()


        # Adjust metrics to get average loss and accuracy per batch
        train_loss /= len(self.train_dataloader)
        train_acc = accuracy_score(y_tr_true, y_tr_pred)



        # Log Training info in W&B
        metrics ={
                      "train/train_loss": train_loss,
                      "train/epoch": (i + 1 + (n_steps_per_epoch * epoch)) / n_steps_per_epoch,
                      "train/train_acc": train_acc,
                  }

        wandb.log(metrics)

        return train_loss, train_acc


    def test_step(self, epoch):

        y_ts_true,  y_ts_pred = [], []

        # Put model in eval mode

        self.model.eval()

        # Setup test loss and test accuracy values
        test_loss, test_acc = 0, 0

        # Turn on inference context manager
        with torch.inference_mode():
            # Loop through DataLoader batches
            for i, data in enumerate(tqdm(self.test_dataloader, desc=f'Epoch {epoch + 1}/{self.epochs}', unit='batch')):
                # Send data to target device
                X_test, y_test = data
                y_ts_true.extend(y_test) # collect all training labels

                y_test = y_test.to(self.device)
                X_test = X_test.to(self.device)

                # 1. Forward pass
                outputs = self.model(X_test)
                _, y_pred = torch.max(outputs, 1) # max along an axis gives both max val as well as index

                y_ts_pred.extend(y_pred.data.cpu())

                # 2. Calculate and accumulate loss
                loss = self.loss_fn(outputs, y_test)
                test_loss += loss.item()

                # Calculate and accumulate accuracy


        # Adjust metrics to get average loss and accuracy per batch
        test_loss/= len(self.test_dataloader)
        test_acc = accuracy_score(y_ts_true, y_ts_pred)



        # Log Testing info in W&B
        metrics ={
                  "test/test_loss": test_loss,
                  "test/test_acc": test_acc,
                  }

        wandb.log(metrics)

        return test_loss, test_acc


    def train(self,
              train_dataloader,
              test_dataloader,
              epochs=1,
              delta = 0,
              patience = 10,
              verbose = False):

        self.epochs = epochs
        self.train_dataloader = train_dataloader
        self.test_dataloader = test_dataloader


        # Create empty results dictionary
        results = {"epoch":[],
                "train_loss": [],
                "train_acc": [],
                "test_loss": [],
                "test_acc": []
        }

        # Make sure model on target device
        self.model.to(self.device)

        # Loop through training and testing steps for a number of epochs
        for epoch in range(self.epochs):
            train_loss, train_acc = self.train_step(epoch)
            test_loss, test_acc = self.test_step(epoch)

            # Print out what's happening
            print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
            )

            # Update results dictionary
            results["epoch"].append(epoch+1)
            results["train_loss"].append(train_loss)
            results["test_loss"].append(test_loss)
            results["train_acc"].append(train_acc)
            results["test_acc"].append(test_acc)



            if self.early_stopping:
                self.check_early_stop(test_loss, delta, verbose, patience)
                if self.early_stop:
                    print("Early Stopping")
                    break

        # Mark the run as finished
        wandb.finish()
        # Return the filled results at the end of the epochs
        return results
# Out:
# wandb: Currently logged in as: viraj08. Use `wandb login --relogin` to force relogin
# wandb version 0.16.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240214_145859-ez85gnoh</code>
# Syncing run <strong><a href='https://wandb.ai/viraj08/vit-b-16/runs/ez85gnoh' target="_blank">engaging-date-1</a></strong> to <a href='https://wandb.ai/viraj08/vit-b-16' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/viraj08/vit-b-16' target="_blank">https://wandb.ai/viraj08/vit-b-16</a>
#  View run at <a href='https://wandb.ai/viraj08/vit-b-16/runs/ez85gnoh' target="_blank">https://wandb.ai/viraj08/vit-b-16/runs/ez85gnoh</a>

# %%
import os
import pathlib
import torch

from PIL import Image
from torch.utils.data import Dataset
import torchvision
from torchvision import transforms
from typing import Tuple, Dict, List

# %% [markdown]
# # Train

# %%
model = torchvision.models.vit_b_16(weights=True)

model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 3)).to(device)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:02<00:00, 140MB/s]

# %%
loss_fn = nn.CrossEntropyLoss(reduction='sum') # computes the cross entropy loss between input logits and target.

optimizer = torch.optim.Adam(model.parameters(), lr = ALPHA)

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Setup training and save the results
Engine = Engine(model=model, loss_fn=loss_fn, optimizer=optimizer, device=device, early_stopping=True)
result = Engine.train(train_dataloader=train_dataloader, test_dataloader=test_dataloader, epochs=EPOCH, verbose=True)

# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
# Out:
# Epoch 1/50: 100%|██████████| 98/98 [01:02<00:00,  1.57batch/s]
# Epoch 1/50: 100%|██████████| 20/20 [00:11<00:00,  1.79batch/s]
# Epoch: 1 | train_loss: 30.1686 | train_acc: 0.6040 | test_loss: 20.2326 | test_acc: 0.7097
# Epoch 2/50: 100%|██████████| 98/98 [00:59<00:00,  1.65batch/s]
# Epoch 2/50: 100%|██████████| 20/20 [00:11<00:00,  1.79batch/s]
# Epoch: 2 | train_loss: 19.7709 | train_acc: 0.7337 | test_loss: 17.1936 | test_acc: 0.7671
# Epoch 3/50: 100%|██████████| 98/98 [00:59<00:00,  1.65batch/s]
# Epoch 3/50: 100%|██████████| 20/20 [00:11<00:00,  1.79batch/s]
# Epoch: 3 | train_loss: 15.0741 | train_acc: 0.8077 | test_loss: 13.6153 | test_acc: 0.8198
# Epoch 4/50: 100%|██████████| 98/98 [00:59<00:00,  1.63batch/s]
# Epoch 4/50: 100%|██████████| 20/20 [00:11<00:00,  1.73batch/s]
# Epoch: 4 | train_loss: 9.4592 | train_acc: 0.8852 | test_loss: 13.7492 | test_acc: 0.8214
# Early stopping counter: 1 out of 10
# Epoch 5/50: 100%|██████████| 98/98 [00:59<00:00,  1.64batch/s]
# Epoch 5/50: 100%|██████████| 20/20 [00:11<00:00,  1.81batch/s]
# Epoch: 5 | train_loss: 5.6514 | train_acc: 0.9410 | test_loss: 14.5120 | test_acc: 0.8278
# Early stopping counter: 2 out of 10
# Epoch 6/50: 100%|██████████| 98/98 [00:59<00:00,  1.64batch/s]
# Epoch 6/50: 100%|██████████| 20/20 [00:11<00:00,  1.79batch/s]
# Epoch: 6 | train_loss: 4.0263 | train_acc: 0.9554 | test_loss: 16.6200 | test_acc: 0.7911
# Early stopping counter: 3 out of 10
# Epoch 7/50: 100%|██████████| 98/98 [00:59<00:00,  1.64batch/s]
# Epoch 7/50: 100%|██████████| 20/20 [00:11<00:00,  1.77batch/s]
# Epoch: 7 | train_loss: 4.8842 | train_acc: 0.9455 | test_loss: 15.2557 | test_acc: 0.8214
# Early stopping counter: 4 out of 10
# Epoch 8/50: 100%|██████████| 98/98 [00:59<00:00,  1.64batch/s]
# Epoch 8/50: 100%|██████████| 20/20 [00:11<00:00,  1.78batch/s]
# Epoch: 8 | train_loss: 2.7896 | train_acc: 0.9703 | test_loss: 14.6762 | test_acc: 0.8373
# Early stopping counter: 5 out of 10
# Epoch 9/50: 100%|██████████| 98/98 [01:00<00:00,  1.63batch/s]
# Epoch 9/50: 100%|██████████| 20/20 [00:11<00:00,  1.79batch/s]
# Epoch: 9 | train_loss: 1.9227 | train_acc: 0.9770 | test_loss: 27.4594 | test_acc: 0.7943
# Early stopping counter: 6 out of 10
# Epoch 10/50: 100%|██████████| 98/98 [00:59<00:00,  1.64batch/s]
# Epoch 10/50: 100%|██████████| 20/20 [00:11<00:00,  1.77batch/s]
# Epoch: 10 | train_loss: 2.3993 | train_acc: 0.9729 | test_loss: 24.0804 | test_acc: 0.7863
# Early stopping counter: 7 out of 10
# Epoch 11/50: 100%|██████████| 98/98 [00:59<00:00,  1.64batch/s]
# Epoch 11/50: 100%|██████████| 20/20 [00:11<00:00,  1.82batch/s]
# Epoch: 11 | train_loss: 2.4769 | train_acc: 0.9684 | test_loss: 15.3868 | test_acc: 0.8581
# Early stopping counter: 8 out of 10
# Epoch 12/50: 100%|██████████| 98/98 [00:59<00:00,  1.64batch/s]
# Epoch 12/50: 100%|██████████| 20/20 [00:11<00:00,  1.81batch/s]
# Epoch: 12 | train_loss: 1.4594 | train_acc: 0.9844 | test_loss: 24.4922 | test_acc: 0.8006
# Early stopping counter: 9 out of 10
# Epoch 13/50: 100%|██████████| 98/98 [00:59<00:00,  1.65batch/s]
# Epoch 13/50: 100%|██████████| 20/20 [00:10<00:00,  1.84batch/s]
# Epoch: 13 | train_loss: 1.8159 | train_acc: 0.9818 | test_loss: 16.7071 | test_acc: 0.8437
# Early stopping counter: 10 out of 10
# Early Stopping
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test/test_acc</td><td>▁▄▆▆▇▅▆▇▅▅█▅▇</td></tr><tr><td>test/test_loss</td><td>▄▃▁▁▁▃▂▂█▆▂▆▃</td></tr><tr><td>train/epoch</td><td>▁▂▂▃▃▄▅▅▆▆▇▇█</td></tr><tr><td>train/train_acc</td><td>▁▃▅▆▇▇▇██████</td></tr><tr><td>train/train_loss</td><td>█▅▄▃▂▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test/test_acc</td><td>0.8437</td></tr><tr><td>test/test_loss</td><td>16.70713</td></tr><tr><td>train/epoch</td><td>36.5</td></tr><tr><td>train/train_acc</td><td>0.98182</td></tr><tr><td>train/train_loss</td><td>1.81593</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">engaging-date-1</strong> at: <a href='https://wandb.ai/viraj08/vit-b-16/runs/ez85gnoh' target="_blank">https://wandb.ai/viraj08/vit-b-16/runs/ez85gnoh</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240214_145859-ez85gnoh/logs</code>
# [INFO] Total training time: 935.156 seconds

# %%
type(model), type(loss_fn), type(optimizer)
# Out:
# (torchvision.models.vision_transformer.VisionTransformer,
#  torch.nn.modules.loss.CrossEntropyLoss,
#  torch.optim.adam.Adam)

# %%
result_df = pd.DataFrame(result)
result_df.head()
# Out:
#    epoch  train_loss  train_acc  test_loss  test_acc
# 0      1   30.168599   0.603954  20.232607  0.709729
# 1      2   19.770945   0.733737  17.193601  0.767145
# 2      3   15.074114   0.807717  13.615313  0.819777
# 3      4    9.459195   0.885204  13.749201  0.821372
# 4      5    5.651417   0.941008  14.511965  0.827751

# %%
result_df.shape
# Out:
# (13, 5)

# %% [markdown]
# # Plot hist

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def plot_torch_hist(hist_df : pd.DataFrame):
    '''
    Args:
      hist_df : pandas Dataframe with five columns
                First column need to be epoch, 'x' values
    '''
    # instantiate figure
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    facecolor = 'cyan'
    fontsize=12

    # Get columns by index to eliminate any column naming error
    x = "epoch"
    y1 = "train_loss"
    y2 = "test_loss"
    y3 = "train_acc"
    y4 = "test_acc"


    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor=facecolor, alpha=0.5)

    # Where was min loss
    best = hist_df[hist_df[y2] == hist_df[y2].min()]

    # pick first axis
    ax = axes[0]

    # Plot all losses
    hist_df.plot(x = x, y = [y1,y2], ax = ax)

    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y2]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr,
            transform=ax.transAxes,
            fontsize=fontsize,
            verticalalignment='top',
            bbox=props)

    # Mark arrow at lowest
    offset = (best[y2].max() - best[y2].max())/10
    ax.annotate(f'Min: {best[y2].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y2].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()-2, best[y2].to_numpy()[0]+offset), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best[x].to_numpy(),
               color = 'green',
               linestyle='-.', lw = 3);

    ax.set_xlabel(x.capitalize())
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid()
    ax.legend(loc = 'upper left') # model legend to upper left

    # pick second axis
    ax = axes[1]

    # Plot accuracy
    hist_df.plot(x = x, y = [y3, y4], ax = ax)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y3],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in lower middle in axes coords
    ax.text(0.3, 0.2, txtstr,
            transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    offset = (best[y4].max() - best[y4].min())/10
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()-2, best[y4].to_numpy()[0]-offset), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw a vertical line at best value
    ax.axvline(x = best[x].to_numpy(),
               color = 'green',
               linestyle='-.', lw = 3)

    # Labels
    ax.set_xlabel(x.capitalize())
    ax.set_ylabel(y3.capitalize())
    ax.set_title('Accuracies')
    ax.grid();
    ax.legend(loc = 'lower left')

    plt.tight_layout()




    # pick first axis
    ax = axes[0]

    # Plot all losses
    hist_df.plot(x = x, y = [y1,y2], ax = ax)

    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y2]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr,
            transform=ax.transAxes,
            fontsize=fontsize,
            verticalalignment='top',
            bbox=props)

    # Mark arrow at lowest
    offset = (best[y2].max() - best[y2].max())/10
    ax.annotate(f'Min: {best[y2].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y2].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()-2, best[y2].to_numpy()[0]+offset), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best[x].to_numpy(),
               color = 'green',
               linestyle='-.', lw = 3);

    ax.set_xlabel(x.capitalize())
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid()
    ax.legend(loc = 'upper left') # model legend to upper left

    # pick second axis
    ax = axes[1]

    # Plot accuracy
    hist_df.plot(x = x, y = [y3, y4], ax = ax)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y3],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in lower middle in axes coords
    ax.text(0.3, 0.2, txtstr,
            transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    offset = (best[y4].max() - best[y4].min())/10
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()-2, best[y4].to_numpy()[0]-offset), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw a vertical line at best value
    ax.axvline(x = best[x].to_numpy(),
               color = 'green',
               linestyle='-.', lw = 3)

    # Labels
    ax.set_xlabel(x.capitalize())
    ax.set_ylabel(y3.capitalize())
    ax.set_title('Accuracies')
    ax.grid();
    ax.legend(loc = 'lower left')

    plt.tight_layout()

# %%
plot_torch_hist(result_df)
